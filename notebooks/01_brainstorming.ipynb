# %% [markdown]
# ## Random table generator
#
# - Take in csv files (Future: also excel)
# - csv file can have any number of coluns, each column has a header/title (within reason)
# - Columns can have different lengths
#
# - need to make an example csv file
# - happy to run in jupyter notebook

# %%
import pandas as pd

# %%
# Function to load csv file

example_table = pd.read_csv("../data/example-table.csv")

# %%
example_table.columns.str.strip()
# Out:
# Index(['Weather', 'Time of day', 'Environment', 'Environmental Hazard',
#        'NPCs'],
#       dtype='str')

# %%
example_table["Weather"]
# Out:
# 0     Sunny
# 1    Stormy
# 2     Snowy
# 3       NaN
# 4       NaN
# 5       NaN
# Name: Weather, dtype: str

# %%
def load_table(filepath):
    example_table = pd.read_csv(filepath)
    example_table.columns.str.strip()
    return example_table

# %%
# Function to remind what categories are available

# %%
# Function that given a category, randomly selects and prints it
